# %%
import logging, sys
sys.path.append("src")
logging.basicConfig(level=logging.INFO, format="%(levelname)s %(name)s: %(message)s")

# %%
from core.vision.yolo_processor import YoloProcessor

yolo = YoloProcessor.from_profile("slam")
# Out:
# [INFO] Loading YOLO model...
# YOLOv12n summary (fused): 159 layers, 2,590,824 parameters, 0 gradients, 6.5 GFLOPs
# [INFO] ✓ YOLOv11 processor initialized (slam) on mps | imgsz=256 | max_det=8 | skip=3
